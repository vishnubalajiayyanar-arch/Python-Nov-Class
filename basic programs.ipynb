# %%
a=("hello")
print(a)
# Out:
# hello

# %%
a=["hello,10,10.5,10j"]
print(a)
print(type(a))
A=("pythonworld")
print(A)
b=10
print(b,type(b))
print(str(b))
print(float(b))
print(bool(b))
print(complex(b))
# Out:
# ['hello,10,10.5,10j']
# <class 'list'>
# pythonworld
# 10 <class 'int'>
# 10
# 10.0
# True
# (10+0j)
