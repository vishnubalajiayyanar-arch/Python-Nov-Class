# %%
a=("hello")
print(a)
# Out:
# hello

# %%
a=["hello,10,10.5,10j"]
print(a)
print(type(a))
A=("pythonworld")
print(A)
b=10
print(b,type(b))
print(str(b))
print(float(b))
print(bool(b))
print(complex(b))
# Out:
# ['hello,10,10.5,10j']
# <class 'list'>
# pythonworld
# 10 <class 'int'>
# 10
# 10.0
# True
# (10+0j)

# %%
a=[10,20,30,40,50,100,200,300]
print(len(a))
a=["apple","mango","orange"]
print(a[1])
print(a[:1])
a[0]="grapes"
print(a)
v=23,34,45,67
h=67,54,43,32
print(v,h,end='/n')
print(v,h,sep='-')
# Out:
# 8
# mango
# ['apple']
# ['grapes', 'mango', 'orange']
# (23, 34, 45, 67) (67, 54, 43, 32)/n(23, 34, 45, 67)-(67, 54, 43, 32)

# %%
b=(float(input("enter the value of base is ")))
h=(float(input("enter the value of hight is")))
pi=3.14
area=pi * b * h
print(area)
print("the area value is b{} and h{} is arae{}".format(b,h,int(area)))
print(f"the area value is b{b} and h{h} is area{area}.")
# Out:
# enter the value of base is 35
# enter the value of hight is24
# 2637.6000000000004
# the area value is b35.0 and h24.0 is arae2637
# the area value is b35.0 and h24.0 is area2637.6000000000004.
