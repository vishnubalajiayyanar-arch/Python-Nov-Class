# %%
#tuple
#tuple is use cricle bracket()
#tuple is immutable
a=(10,12,18)
print(type(a))
#tuple is take all type of int float sring bool and complex
A=("hi",10.5,10,10j)
print(type (A),A[1])
print(a[2])
print(a[-2])
print(A[1:4])
print(A[:2])
print(A[::2])
print(A[::-2])
print(id(A))
print(len(A))
b=[A]
print(b)
print(type(b))
# Out:
# <class 'tuple'>
# <class 'tuple'> 10.5
# 18
# 12
# (10.5, 10, 10j)
# ('hi', 10.5)
# ('hi', 10)
# (10j, 10.5)
# 4372551120
# 4
# [('hi', 10.5, 10, 10j)]
# <class 'list'>
# [('hi', 10.5, 10, 10j)]

# %%
#set set()is a key world its immutable
e=set(["hi",10,10.5,25j])
print(type(e))
# Out:
# <class 'set'>
