# %%
#string methods
#uppercase
a=("python")
print(a.upper())
#lowercase
b=(a)
print(b.lower())
#capitalize
print(a.capitalize())
#title
c=(a+b)
print(c.title())
#swapcase
A=("python")
print((A.swapcase()),(c.swapcase()))
#strip
r="   python program "
print(r.strip())
#replace
print(r.replace("program","basic"))
#join
g=["python","program","is","fun"]
print("".join(g))
#count
f=[1,2,3,22,42,4,29,33]
count_2=f.count(2)
print(f"the letter of 2 is inside the f is{count_2} times in a.")
#find
j="program"
index=r.find(j)
print(f"the j is {j}start index:{index}")
# Out:
# PYTHON
# python
# Python
# Pythonpython
# PYTHON PYTHONPYTHON
# python program
#    python basic
# pythonprogramisfun
# the letter of 2 is inside the f is1 times in a.
# the j is programstart index:10
